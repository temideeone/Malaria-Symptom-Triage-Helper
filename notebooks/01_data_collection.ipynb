# %% [markdown]
# # Malaria Symptom Triage Helper
#
# ## Phase 1: Dataset Collection and Understanding
#
# ### Project Objective
#
# The aim of this project is to develop a machine learning-based malaria symptom triage helper capable of predicting malaria risk using patient-reported symptoms. The system is intended to support healthcare decision-making and encourage timely medical evaluation.
#
# ### Dataset Requirements
#
# The selected dataset should:
#
# * Contain symptom-related features.
# * Include a diagnosis or outcome variable.
# * Be suitable for supervised machine learning classification.
# * Contain sufficient observations for model training and evaluation.
# * Be publicly available for academic purposes.
#
# ### Expected Outcome
#
# A suitable dataset will be identified, documented, and prepared for preprocessing and exploratory data analysis.

# %%
import pandas as pd

df = pd.read_csv("../data/raw/malaria_disease.csv")

df.head()
# Out:
#   patient_id  age sex  pregnant                    location  \
# 0     P00001   15   F     False  Sub-Saharan Africa - Rural
# 1     P00002   27   F     False       Latin America - Urban
# 2     P00003   21   F     False            Papua New Guinea
# 3     P00004   17   F     False      Southeast Asia - Rural
# 4     P00005   13   F     False  Sub-Saharan Africa - Urban
#
#    travel_history_endemic_area  bed_net_use  irs_spraying  \
# 0                        False        False          True
# 1                        False        False         False
# 2                        False         True         False
# 3                        False         True          True
# 4                         True         True         False
#
#    previous_malaria_episodes  fever  ...  pcr_positive  glucose_mg_dl  \
# 0                          3   True  ...          True            106
# 1                          0  False  ...         False             80
# ...

# %% [markdown]
# ## Dataset Shape
#
# This step determines the number of observations (rows) and features (columns) available in the dataset.

# %%
df.shape
# Out:
# (5000, 37)

# %% [markdown]
# ## Feature Overview
#
# This section lists all variables contained in the dataset.

# %%
df.columns.tolist()
# Out:
# ['patient_id',
#  'age',
#  'sex',
#  'pregnant',
#  'location',
#  'travel_history_endemic_area',
#  'bed_net_use',
#  'irs_spraying',
#  'previous_malaria_episodes',
#  'fever',
#  'chills_rigors',
#  'headache',
#  'night_sweats',
#  'fatigue_malaise',
#  'nausea_vomiting',
#  'diarrhea',
#  'cough',
#  'abdominal_pain',
#  'jaundice',
#  'altered_consciousness',
#  'seizures',
#  'hemoglobin_g_dl',
#  'platelets_x10e9_l',
#  'wbc_x10e9_l',
#  'parasitemia_percent',
#  'rdt_positive',
#  'microscopy_positive',
#  'pcr_positive',
#  'glucose_mg_dl',
#  'creatinine_mg_dl',
#  'bilirubin_mg_dl',
#  'lactate_mmol_l',
#  'plasmodium_species',
#  'severity',
#  'treatment_received',
#  'outcome',
#  'diagnosis']

# %% [markdown]
# ## Data Types
#
# This section identifies the data type of each feature and helps determine preprocessing requirements.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   patient_id                   5000 non-null   str
#  1   age                          5000 non-null   int64
#  2   sex                          5000 non-null   str
#  3   pregnant                     5000 non-null   bool
#  4   location                     5000 non-null   str
#  5   travel_history_endemic_area  5000 non-null   bool
#  6   bed_net_use                  5000 non-null   bool
#  7   irs_spraying                 5000 non-null   bool
#  8   previous_malaria_episodes    5000 non-null   int64
#  9   fever                        5000 non-null   bool
#  10  chills_rigors                5000 non-null   bool
#  11  headache                     5000 non-null   bool
#  12  night_sweats                 5000 non-null   bool
# ...

# %% [markdown]
# ## Statistical Summary
#
# This section provides descriptive statistics for both numerical and categorical variables.

# %%
df.describe(include="all")
# Out:
#        patient_id          age   sex pregnant          location  \
# count        5000  5000.000000  5000     5000              5000
# unique       5000          NaN     2        2                16
# top        P00001          NaN     M    False  Papua New Guinea
# freq            1          NaN  2511     4939               582
# mean          NaN    17.129600   NaN      NaN               NaN
# std           NaN    18.606796   NaN      NaN               NaN
# min           NaN     0.000000   NaN      NaN               NaN
# 25%           NaN     3.000000   NaN      NaN               NaN
# 50%           NaN    10.000000   NaN      NaN               NaN
# 75%           NaN    25.000000   NaN      NaN               NaN
# max           NaN    80.000000   NaN      NaN               NaN
#
#        travel_history_endemic_area bed_net_use irs_spraying  \
# count                         5000        5000         5000
# unique                           2           2            2
# ...

# %% [markdown]
# ## Missing Value Analysis
#
# This section identifies features with missing values that may require cleaning or imputation.

# %%
df.isnull().sum()
# Out:
# patient_id                     0
# age                            0
# sex                            0
# pregnant                       0
# location                       0
# travel_history_endemic_area    0
# bed_net_use                    0
# irs_spraying                   0
# previous_malaria_episodes      0
# fever                          0
# chills_rigors                  0
# headache                       0
# night_sweats                   0
# fatigue_malaise                0
# nausea_vomiting                0
# diarrhea                       0
# cough                          0
# abdominal_pain                 0
# jaundice                       0
# altered_consciousness          0
# seizures                       0
# hemoglobin_g_dl                0
# platelets_x10e9_l              0
# wbc_x10e9_l                    0
# parasitemia_percent            0
# rdt_positive                   0
# microscopy_positive            0
# pcr_positive                   0
# ...

# %% [markdown]
# ## Duplicate Record Analysis
#
# This step checks whether duplicate observations exist in the dataset.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
